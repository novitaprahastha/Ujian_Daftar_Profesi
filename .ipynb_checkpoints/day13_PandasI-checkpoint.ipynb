# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # SERIES

# %%
#SERIES
#untuk panggil sesuai index => y[0]
x = [4,6,5,7,8,9,3,2,4,5,7]
y = pd.Series(x)
y
# Out:
# 0     4
# 1     6
# 2     5
# 3     7
# 4     8
# 5     9
# 6     3
# 7     2
# 8     4
# 9     5
# 10    7
# dtype: int64

# %%
x = [4,6,5,7,8,9,3,2,4,5,7]
y = pd.Series(np.array(x))
y
# Out:
# 0     4
# 1     6
# 2     5
# 3     7
# 4     8
# 5     9
# 6     3
# 7     2
# 8     4
# 9     5
# 10    7
# dtype: int64

# %%
x = ['andi','budi','caca']
y = pd.Series(np.array(x))
y
# Out:
# 0    andi
# 1    budi
# 2    caca
# dtype: object

# %%
y[1::]
# Out:
# 1    budi
# 2    caca
# dtype: object

# %%
#UNTUK GANTI INDEXNYA
x = [4,6,5,7,8]
y = pd.Series(np.array(x), index = ['a','b','c','d','e'])
y
# Out:
# a    4
# b    6
# c    5
# d    7
# e    8
# dtype: int64

# %%
y['a']
# Out:
# 4

# %%
#KASIH NAMA SERIES 
x = [4,6,5,7,8]
y = pd.Series(np.array(x), index = ['a','b','c','d','e'], name = 'Test')
y
# Out:
# a    4
# b    6
# c    5
# d    7
# e    8
# Name: Test, dtype: int64

# %%
#DICT (key nya jadi index)
y = pd.Series(
    data = {'a':2,'b':3},
    name = 'Test'
)
y
# Out:
# a    2
# b    3
# Name: Test, dtype: int64

# %%
#DATAFRAME
x = [2,4,6,8,10]
# x = np.array(x) => bisa pakai numpy array
df = pd.DataFrame(x, columns = ['Nilai'])
df
# Out:
#    Nilai
# 0      2
# 1      4
# 2      6
# 3      8
# 4     10

# %%
df.shape #(5,1)=> baris =5, kol = 1
# Out:
# (5, 1)

# %%
x = [2,4,6,8,10]
y = [1,3,5,7,9]
df = pd.DataFrame([x,y]) #=> jadi 5 col 
df
# Out:
#    0  1  2  3   4
# 0  2  4  6  8  10
# 1  1  3  5  7   9

# %%
#KL MAU HANYA 2 COL
x = [[1,2], [3,4], [5,6], [7,8]]
df = pd.DataFrame(x)
df
# Out:
#    0  1
# 0  1  2
# 1  3  4
# 2  5  6
# 3  7  8

# %%
#bikin dataframe yang diubah list dalam list
x = [2,4,6,8,10]
y = [1,3,5,7,9]
z = map(lambda a,b: [a,b], x,y)
z = list(z)
df = pd.DataFrame(z) #=> jadi 2 col 
df
# Out:
#     0  1
# 0   2  1
# 1   4  3
# 2   6  5
# 3   8  7
# 4  10  9

# %%
df[0] #=> mengeluarkan col ke 0
# Out:
# 0     2
# 1     4
# 2     6
# 3     8
# 4    10
# Name: 0, dtype: int64

# %%
#buat langsung 2 kolom tanpa lamda 
x = [2,4,6,8,10]
y = [1,3,5,7,9]
df = pd.DataFrame()
df['X'] = x
df['Y'] = y
df
# Out:
#     X  Y
# 0   2  1
# 1   4  3
# 2   6  5
# 3   8  7
# 4  10  9

# %%
x = [2,4,6,8,10]
y = [1,3,5,7,9]
df = pd.DataFrame(np.array(x), columns =['Nilai'])
df
# Out:
#    Nilai
# 0      2
# 1      4
# 2      6
# 3      8
# 4     10

# %%
data = [
    ['Putu', 'Denpasar', 'PNS'],
    ['Kadek', 'Jakarta', 'Siswa'],
    ['Nyoman', 'Bekasi', 'Petani'],
    
]
dfData = pd.DataFrame(
    data, index= list('abc'),
    columns = ['Nama', 'Kota', 'Pekerjaan'])
dfData
# Out:
#      Nama      Kota Pekerjaan
# a    Putu  Denpasar       PNS
# b   Kadek   Jakarta     Siswa
# c  Nyoman    Bekasi    Petani

# %%
#DATAFRAME DARI DICT YANG ADA LISTNYA
data = {
    'x': [898,878,656],
    'y': [999,726,736],
    'z': [647,727,638]
}
df = pd.DataFrame(data)
df
# Out:
#      x    y    z
# 0  898  999  647
# 1  878  726  727
# 2  656  736  638

# %%
#DATAFRAME DARI LIST OF DICT 
data = [
    {'nama': "Putu", 'kota': "Jakarta"},
    {'nama': "Kadek", 'kota': "Jakarta"},
    {'nama': "Nyoman", 'kota': "Jakarta"},
    {'nama': "Ketut", 'kota': 'Jakarta', 'job': "PNS"},
]
df = pd.DataFrame(data)
df
# Out:
#      nama     kota  job
# 0    Putu  Jakarta  NaN
# 1   Kadek  Jakarta  NaN
# 2  Nyoman  Jakarta  NaN
# 3   Ketut  Jakarta  PNS

# %%
#BUAT DATAFRAME DARI SERIES

x =[1,2,3,4,5]
x = pd.Series(x, name = 'Test')
df = pd.DataFrame(x)
df
# Out:
#    Test
# 0     1
# 1     2
# 2     3
# 3     4
# 4     5

# %%
x =[1,2,3,4,5]
x = pd.Series(x, name = 'Test')
y = [1,2,3,4,5]
y = pd.Series(y, name = 'Try')
df = pd.DataFrame({
    'Col.X' : x,
    'Col.Y' : y
})
df
# Out:
#    Col.X  Col.Y
# 0      1      1
# 1      2      2
# 2      3      3
# 3      4      4
# 4      5      5

# %%
x =[1,2,3,4,5]
x = pd.Series(x, name = 'Test')
y = [1,2,3,4,5]
y = pd.Series(y, name = 'Try')
df = pd.DataFrame({
    x.name : x,
    y.name : y
})
df
# Out:
#    Test  Try
# 0     1    1
# 1     2    2
# 2     3    3
# 3     4    4
# 4     5    5

# %%
df = pd.DataFrame({
    'A': np.arange(20,26),
    'B': [54,8,97,67,23,45],
    'C': 99,
    'D' : np.ones(6)
})
df
# Out:
#     A   B   C    D
# 0  20  54  99  1.0
# 1  21   8  99  1.0
# 2  22  97  99  1.0
# 3  23  67  99  1.0
# 4  24  23  99  1.0
# 5  25  45  99  1.0

# %%
df.head(6)
# Out:
#     A   B   C    D
# 0  20  54  99  1.0
# 1  21   8  99  1.0
# 2  22  97  99  1.0
# 3  23  67  99  1.0
# 4  24  23  99  1.0
# 5  25  45  99  1.0

# %%
list(df.index)
# Out:
# [0, 1, 2, 3, 4, 5]

# %%
list(df.columns)
# Out:
# ['A', 'B', 'C', 'D']

# %%
df.values #=> untuk ubah jadi numpy array
# Out:
# array([[20., 54., 99.,  1.],
#        [21.,  8., 99.,  1.],
#        [22., 97., 99.,  1.],
#        [23., 67., 99.,  1.],
#        [24., 23., 99.,  1.],
#        [25., 45., 99.,  1.]])

# %%
df.describe()
# Out:
#                A          B     C    D
# count   6.000000   6.000000   6.0  6.0
# mean   22.500000  49.000000  99.0  1.0
# std     1.870829  31.704889   0.0  0.0
# min    20.000000   8.000000  99.0  1.0
# 25%    21.250000  28.500000  99.0  1.0
# 50%    22.500000  49.500000  99.0  1.0
# 75%    23.750000  63.750000  99.0  1.0
# max    25.000000  97.000000  99.0  1.0

# %%
df['A'].values
# Out:
# array([20, 21, 22, 23, 24, 25])

# %%
df.sort_index(ascending=False)
# Out:
#     A   B   C    D
# 5  25  45  99  1.0
# 4  24  23  99  1.0
# 3  23  67  99  1.0
# 2  22  97  99  1.0
# 1  21   8  99  1.0
# 0  20  54  99  1.0

# %%
df.sort_index(ascending=False, axis = 1)
# Out:
#      D   C   B   A
# 0  1.0  99  54  20
# 1  1.0  99   8  21
# 2  1.0  99  97  22
# 3  1.0  99  67  23
# 4  1.0  99  23  24
# 5  1.0  99  45  25

# %%
df.sort_index(ascending=False, axis = 1)
df
# Out:
#     A   B   C    D
# 0  20  54  99  1.0
# 1  21   8  99  1.0
# 2  22  97  99  1.0
# 3  23  67  99  1.0
# 4  24  23  99  1.0
# 5  25  45  99  1.0

# %%
df.sort_index(ascending=False, axis = 1, inplace = True)
df
# Out:
#      D   C   B   A
# 0  1.0  99  54  20
# 1  1.0  99   8  21
# 2  1.0  99  97  22
# 3  1.0  99  67  23
# 4  1.0  99  23  24
# 5  1.0  99  45  25

# %%
df.sort_values(by='B')
# Out:
#      D   C   B   A
# 1  1.0  99   8  21
# 4  1.0  99  23  24
# 5  1.0  99  45  25
# 0  1.0  99  54  20
# 3  1.0  99  67  23
# 2  1.0  99  97  22

# %%
df.sort_values(by=['A','B'], ascending = False)
# Out:
#      D   C   B   A
# 5  1.0  99  45  25
# 4  1.0  99  23  24
# 3  1.0  99  67  23
# 2  1.0  99  97  22
# 1  1.0  99   8  21
# 0  1.0  99  54  20

# %%
df.sort_values(by=['A','B'], ascending = [False, True])
# Out:
#      D   C   B   A
# 5  1.0  99  45  25
# 4  1.0  99  23  24
# 3  1.0  99  67  23
# 2  1.0  99  97  22
# 1  1.0  99   8  21
# 0  1.0  99  54  20

# %%
df[['A', 'C']]
# Out:
#     A   C
# 0  20  99
# 1  21  99
# 2  22  99
# 3  23  99
# 4  24  99
# 5  25  99

# %%
df[0:3]
# Out:
#      D   C   B   A
# 0  1.0  99  54  20
# 1  1.0  99   8  21
# 2  1.0  99  97  22

# %%
df[::2]
# Out:
#      D   C   B   A
# 0  1.0  99  54  20
# 2  1.0  99  97  22
# 4  1.0  99  23  24

# %%
df.loc[0] #LOC => PARAMETER PERTAMA HARUS BARISNYA DULU
# Out:
# D     1.0
# C    99.0
# B    54.0
# A    20.0
# Name: 0, dtype: float64

# %%
df.loc[0:2]
# Out:
#      D   C   B   A
# 0  1.0  99  54  20
# 1  1.0  99   8  21
# 2  1.0  99  97  22

# %%
df
# Out:
#      D   C   B   A
# 0  1.0  99  54  20
# 1  1.0  99   8  21
# 2  1.0  99  97  22
# 3  1.0  99  67  23
# 4  1.0  99  23  24
# 5  1.0  99  45  25

# %%
df.loc[0,'A']
# Out:
# 20

# %%
#LOC CALL BY NAME
df.loc[1, ['B', 'D']]
# Out:
# B    8.0
# D    1.0
# Name: 1, dtype: float64

# %%
#SET INDEX
df = df.set_index('D')
df
# Out:
#       C   B
# D
# 1.0  99  54
# 1.0  99   8
# 1.0  99  97
# 1.0  99  67
# 1.0  99  23
# 1.0  99  45

# %%
df = pd.DataFrame({
    'A': np.arange(20,26),
    'B': [54,8,97,67,23,45],
    'C': 99,
    'D' : np.ones(6)
})
df.set_index('A')
# Out:
#      B   C    D
# A
# 20  54  99  1.0
# 21   8  99  1.0
# 22  97  99  1.0
# 23  67  99  1.0
# 24  23  99  1.0
# 25  45  99  1.0

# %%
df.index = df['A'] #=> A sebagai indeks, tetapi A juga ada pada kolom 
df
# Out:
#      A   B   C    D
# A
# 20  20  54  99  1.0
# 21  21   8  99  1.0
# 22  22  97  99  1.0
# 23  23  67  99  1.0
# 24  24  23  99  1.0
# 25  25  45  99  1.0

# %%
#ILOC CALL BY URUTAN INDEX = INT
df.loc[20, 'A'] #=> INDEKS KE a, KOL KE A
# df.iloc[0,0] #=> INDEKS KE O KOL KE O 
# df.loc[:,'A']
# Out:
# 20

# %%
df.iloc[3:5, 0:3] #indeks ke 3-4, kolom 0-3
# Out:
#      A   B   C
# A
# 23  23  67  99
# 24  24  23  99

# %%
#MERUBAH NAMA KOLOM
df.index = list('abcdef')
df.columns = ['Nama', 'Nilai', 'Value', 'Ranking']
df
# Out:
#    Nama  Nilai  Value  Ranking
# a    20     54     99      1.0
# b    21      8     99      1.0
# c    22     97     99      1.0
# d    23     67     99      1.0
# e    24     23     99      1.0
# f    25     45     99      1.0

# %%
df.iloc[::2].sort_values(
    by = ['Nilai', 'Value'],
    ascending = [False, True])
# Out:
#    Nama  Nilai  Value  Ranking
# c    22     97     99      1.0
# a    20     54     99      1.0
# e    24     23     99      1.0

# %%
df.iloc[::2].sort_values(
    by = ['Nilai', 'Value'],
    ascending = [False, True]
)[['Nama', 'Nilai']]
# Out:
#    Nama  Nilai
# c    22     97
# a    20     54
# e    24     23

# %% [markdown]
# # READ CSV, JSON, EXCEL, MONGODB DAN SQL

# %%
mydf = pd.read_csv('datapand.csv')
mydf
# Out:
#    no    nama       kota
# 0   1    Putu   Denpasar
# 1   2   Kadek        BSD
# 2   3  Nyoman  Tangerang

# %%
df = pd.read_excel('X.xlsx')
df
# Out:
#     Nomor                       Nama                Posisi              Negara
# 0       1            Hector Bellerin            Right Back               Spain
# 1       2                 Mesut Ozil            Midfielder             Germany
# 2       3          Emiliano Martinez            Goalkeeper           Argentina
# 3       4             Calum Chambers              Defender             England
# 4       5                 Matt Macey            Goalkeeper             England
# 5       6     Ainsley Maitland-Niles            Midfielder             England
# 6       7             Kieran Tierney              Defender            Scotland
# 7       8        Alexandre Lacazette               Forward              France
# 8       9           Shkodran Mustafi              Defender             Germany
# 9      10                 David Luiz              Defender              Brazil
# 10     11  Sokratis Papastathopoulos              Defender              Greece
# ...

# %%
df = pd.read_json('file.json')
df
# Out:
#    no  nama      kota
# 0   1  Andi   Jakarta
# 1   2  Budi   Bandung
# 2   3  Caca  Surabaya

# %%
df['nama']
# Out:
# 0    Andi
# 1    Budi
# 2    Caca
# Name: nama, dtype: object

# %%
df[['nama', 'kota']]
# Out:
#    nama      kota
# 0  Andi   Jakarta
# 1  Budi   Bandung
# 2  Caca  Surabaya

# %%
df[['no', 'nama']]
# Out:
#    no  nama
# 0   1  Andi
# 1   2  Budi
# 2   3  Caca

# %%
#LATIHAN 
# create dataframe:
#     csv
#     excel
#     json

# create dataframe;
#     db mysql
#     db mongodb

# %%
#DATAFRAME DARI CSV
import csv
data = open('file.csv', 'r') 
x = csv.reader(data)
x= list(x)
x
# Out:
# [['no', 'nama', 'kota'],
#  ['1.0', 'Andi', 'Jakarta'],
#  ['2.0', 'Budi', 'Bandung'],
#  ['3.0', 'Caca', 'Surabaya']]

# %%
df = pd.DataFrame(x[1:], columns = x[0])
df
# Out:
#     no  nama      kota
# 0  1.0  Andi   Jakarta
# 1  2.0  Budi   Bandung
# 2  3.0  Caca  Surabaya

# %%
#DATAFRAME DARI JSON
import json 
with open('file.json', 'r') as x:
    out = json.load(x)
out
# Out:
# [{'no': 1, 'nama': 'Andi', 'kota': 'Jakarta'},
#  {'no': 2, 'nama': 'Budi', 'kota': 'Bandung'},
#  {'no': 3, 'nama': 'Caca', 'kota': 'Surabaya'}]

# %%
df = pd.DataFrame(out)
df
# Out:
#    no  nama      kota
# 0   1  Andi   Jakarta
# 1   2  Budi   Bandung
# 2   3  Caca  Surabaya

# %%
#DATAFRAME DARI EXCEL
import xlrd 
data = xlrd.open_workbook('X.xlsx')
sheet1 = data.sheet_by_index(0)
data1= []
for i in range (sheet1.nrows):
    data1.append(sheet1.row_values(i))
data1
# Out:
# [['Nomor', 'Nama', 'Posisi', 'Negara'],
#  [1.0, 'Hector Bellerin', 'Right Back', 'Spain'],
#  [2.0, 'Mesut Ozil', 'Midfielder', 'Germany'],
#  [3.0, 'Emiliano Martinez', 'Goalkeeper', 'Argentina'],
#  [4.0, 'Calum Chambers', 'Defender', 'England'],
#  [5.0, 'Matt Macey', 'Goalkeeper', 'England'],
#  [6.0, 'Ainsley Maitland-Niles', 'Midfielder', 'England'],
#  [7.0, 'Kieran Tierney', 'Defender', 'Scotland'],
#  [8.0, 'Alexandre Lacazette', 'Forward', 'France'],
#  [9.0, 'Shkodran Mustafi', 'Defender', 'Germany'],
#  [10.0, 'David Luiz', 'Defender', 'Brazil'],
#  [11.0, 'Sokratis Papastathopoulos', 'Defender', 'Greece'],
#  [12.0, 'Pierre-Emerick Aubameyang', 'Forward', 'Gabon'],
#  [13.0, 'Bernd Leno', 'Goalkeeper', 'Germany'],
#  [14.0, 'Daniel Ceballos', 'Centre Midfielder', 'Spain'],
#  [15.0, 'Granit Xhaka', 'Midfielder', 'Switzerland'],
#  [16.0, 'Rob Holding', 'Centre Back', 'England'],
#  [17.0, 'Sead Kolasinac', 'Defender', 'Bosnia-Herzegovina'],
# ...

# %%
df = pd.DataFrame(data1[1:], columns=data1[0])
df
# Out:
#     Nomor                       Nama                Posisi              Negara
# 0     1.0            Hector Bellerin            Right Back               Spain
# 1     2.0                 Mesut Ozil            Midfielder             Germany
# 2     3.0          Emiliano Martinez            Goalkeeper           Argentina
# 3     4.0             Calum Chambers              Defender             England
# 4     5.0                 Matt Macey            Goalkeeper             England
# 5     6.0     Ainsley Maitland-Niles            Midfielder             England
# 6     7.0             Kieran Tierney              Defender            Scotland
# 7     8.0        Alexandre Lacazette               Forward              France
# 8     9.0           Shkodran Mustafi              Defender             Germany
# 9    10.0                 David Luiz              Defender              Brazil
# 10   11.0  Sokratis Papastathopoulos              Defender              Greece
# ...

# %%
#DATAFRAME FROM DB SQL 
import mysql.connector 

db = mysql.connector.connect(
    host = 'localhost',
    port = 3306,
    user = 'root',
    passwd = '1992Kadek',
    database = 'ptABC',
)
c = db.cursor()
sql = 'select * from karyawan'
c.execute(sql)
data = c.fetchall()
data
# Out:
# [(1,
#   None,
#   5000000,
#   'Hani',
#   {'wanita'},
#   datetime.datetime(2019, 11, 21, 9, 35, 47),
#   None),
#  (3,
#   None,
#   5000000,
#   'Budi',
#   {'pria'},
#   datetime.datetime(2019, 11, 21, 9, 44, 10),
#   None),
#  (4,
#   None,
#   7500000,
#   'Dina',
#   {'wanita'},
#   datetime.datetime(2019, 11, 21, 9, 40, 24),
#   None),
#  (5,
#   None,
#   5000000,
#   'Budi',
#   {'pria'},
#   datetime.datetime(2019, 11, 21, 9, 40, 24),
#   None),
#  (6,
#   None,
#   12000000,
#   'Budi',
#   None,
#   datetime.datetime(2019, 11, 21, 9, 56, 16),
#   None),
#  (9,
#   None,
#   20000000,
#   'Zizi',
#   None,
#   datetime.datetime(2019, 11, 21, 12, 0, 38),
#   None)]

# %%
df = pd.DataFrame(x)
df
# Out:
#    0     1         2     3         4                   5     6
# 0  1  None   5000000  Hani  {wanita} 2019-11-21 09:35:47  None
# 1  3  None   5000000  Budi    {pria} 2019-11-21 09:44:10  None
# 2  4  None   7500000  Dina  {wanita} 2019-11-21 09:40:24  None
# 3  5  None   5000000  Budi    {pria} 2019-11-21 09:40:24  None
# 4  6  None  12000000  Budi      None 2019-11-21 09:56:16  None
# 5  9  None  20000000  Zizi      None 2019-11-21 12:00:38  None

# %%
c = db.cursor()
sql = 'describe karyawan'
c.execute(sql)
x = c.fetchall()
# x
listHeader = []
for i in x:
#     print(i[0])
    listHeader.append(i[0])
print(listHeader)
# Out:
# ['id_kar', 'alamat', 'gaji', 'nama', 'gender', 'created_at', 'hobby']

# %%
df = pd.DataFrame(data, columns = listHeader)
df
# Out:
#    id_kar alamat      gaji  nama    gender          created_at hobby
# 0       1   None   5000000  Hani  {wanita} 2019-11-21 09:35:47  None
# 1       3   None   5000000  Budi    {pria} 2019-11-21 09:44:10  None
# 2       4   None   7500000  Dina  {wanita} 2019-11-21 09:40:24  None
# 3       5   None   5000000  Budi    {pria} 2019-11-21 09:40:24  None
# 4       6   None  12000000  Budi      None 2019-11-21 09:56:16  None
# 5       9   None  20000000  Zizi      None 2019-11-21 12:00:38  None

# %%
#DATAFRAME DARI MONGODB
import pymongo
dburl = 'mongodb://localhost:27017/'
mymongo = pymongo.MongoClient(dburl)
mycol = mymongo['resto']
data = list(mycol.resto.find())
data
# Out:
# [{'_id': ObjectId('5ddb68d1578412652890a12c'),
#   'address': {'building': '2780',
#    'coord': [-73.98241999999999, 40.579505],
#    'street': 'Stillwell Avenue',
#    'zipcode': '11224'},
#   'borough': 'Brooklyn',
#   'cuisine': 'American ',
#   'grades': [{'date': datetime.datetime(2014, 6, 10, 0, 0),
#     'grade': 'A',
#     'score': 5},
#    {'date': datetime.datetime(2013, 6, 5, 0, 0), 'grade': 'A', 'score': 7},
#    {'date': datetime.datetime(2012, 4, 13, 0, 0), 'grade': 'A', 'score': 12},
#    {'date': datetime.datetime(2011, 10, 12, 0, 0), 'grade': 'A', 'score': 12}],
#   'name': 'Riviera Caterer',
#   'restaurant_id': '40356018'},
#  {'_id': ObjectId('5ddb68d1578412652890a12d'),
#   'address': {'building': '469',
#    'coord': [-73.961704, 40.662942],
#    'street': 'Flatbush Avenue',
#    'zipcode': '11225'},
#   'borough': 'Brooklyn',
#   'cuisine': 'Hamburgers',
#   'grades': [{'date': datetime.datetime(2014, 12, 30, 0, 0),
#     'grade': 'A',
#     'score': 8},
# ...

# %%
df = pd.DataFrame(data)
df
# Out:
#                            _id  \
# 0     5ddb68d1578412652890a12c
# 1     5ddb68d1578412652890a12d
# 2     5ddb68d1578412652890a12e
# 3     5ddb68d1578412652890a12f
# 4     5ddb68d1578412652890a130
# ...                        ...
# 3767  5ddb68d1578412652890afe3
# 3768  5ddb68d1578412652890afe4
# 3769  5ddb68d1578412652890afe5
# 3770  5ddb68d1578412652890afe6
# 3771  5ddb68d1578412652890afe7
#
#                                                 address    borough  \
# 0     {'building': '2780', 'coord': [-73.98241999999...   Brooklyn
# 1     {'building': '469', 'coord': [-73.961704, 40.6...   Brooklyn
# 2     {'building': '1007', 'coord': [-73.856077, 40....      Bronx
# 3     {'building': '351', 'coord': [-73.985135599999...  Manhattan
# 4     {'building': '97-22', 'coord': [-73.8601152, 4...     Queens
# ...                                                 ...        ...
# 3767  {'building': '451', 'coord': [-73.9462238, 40....   Brooklyn
# ...

# %%
df.head(10)
# Out:
#                         _id  \
# 0  5ddb68d1578412652890a12c
# 1  5ddb68d1578412652890a12d
# 2  5ddb68d1578412652890a12e
# 3  5ddb68d1578412652890a12f
# 4  5ddb68d1578412652890a130
# 5  5ddb68d1578412652890a131
# 6  5ddb68d1578412652890a132
# 7  5ddb68d1578412652890a133
# 8  5ddb68d1578412652890a134
# 9  5ddb68d1578412652890a135
#
#                                              address        borough  \
# 0  {'building': '2780', 'coord': [-73.98241999999...       Brooklyn
# 1  {'building': '469', 'coord': [-73.961704, 40.6...       Brooklyn
# 2  {'building': '1007', 'coord': [-73.856077, 40....          Bronx
# 3  {'building': '351', 'coord': [-73.985135599999...      Manhattan
# 4  {'building': '97-22', 'coord': [-73.8601152, 4...         Queens
# 5  {'building': '2206', 'coord': [-74.1377286, 40...  Staten Island
# 6  {'building': '8825', 'coord': [-73.8803827, 40...         Queens
# 7  {'building': '7114', 'coord': [-73.9068506, 40...       Brooklyn
# ...
